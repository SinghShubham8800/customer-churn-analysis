# %% [markdown]
# ## 1. Import database / data

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

print("Pandas version:", pd.__version__)
print("Numpy version:", np.__version__)
print("Seaborn version:", sns.__version__)
print("All libraries imported successfully!")
# Out:
# Pandas version: 3.0.5
# Numpy version: 2.5.2
# Seaborn version: 0.13.2
# All libraries imported successfully!

# %%
# Import/Connect database/Data with python

conn = sqlite3.connect('customer_churn.db')

# SQL query to Get all table names
sql_query = """
        SELECT name
        FROM sqlite_master
        WHERE type = 'table';
"""

# Store value in "table" named variable
tables = pd.read_sql(sql_query, conn)

# Create dataframe/Seprate for each table
for table_name in tables['name']:
    df = pd.read_sql(f"SELECT * FROM {table_name}", conn) # Read table into dataframe
    globals()[f"df_{table_name}"] = df                    # Create dynamic dataframe name
    print(f"Created dataframe: df_{table_name}")

# Close connection
conn.close()
# Out:
# Created dataframe: df_db_customer
# Created dataframe: df_db_subscription
# Created dataframe: df_db_support

# %%
# Print table names and column names
conn = sqlite3.connect('customer_churn.db')

for table_name in tables['name']:
    print(f"\nTable Name: {table_name}")
    # Get column information
    # PRAGMA is a special command in SQLite used to:
    # Inspect db information, control db settings, retrieve metadata about tables
    columns_query = f"PRAGMA table_info({table_name});"
    columns = pd.read_sql(columns_query, conn)
    print("Columns:")
    print(columns['name'].tolist())

# Close connection
conn.close()
# Out:
# Table Name: db_customer
# Columns:
# ['customerid', 'name', 'country', 'state', 'gender', 'dob', 'interests', 'pincode']
#
# Table Name: db_subscription
# Columns:
# ['customerid', 'subscription_start_date', 'subscription_type', 'renewal_date', 'plan_type', 'contract_type', 'cancellation_date', 'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score']
#
# Table Name: db_support
# Columns:
# ['customerid', 'complaint_date', 'escalations', 'csat_score', 'col_1', 'comment']

# %%
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  21 non-null     str
#  1   name        21 non-null     str
#  2   country     18 non-null     str
#  3   state       21 non-null     str
#  4   gender      21 non-null     str
#  5   dob         21 non-null     str
#  6   interests   4 non-null      str
#  7   pincode     0 non-null      object
# dtypes: object(1), str(7)
# memory usage: 1.4+ KB

# %% [markdown]
# ## 2. Data cleaning
# ### On Customer table

# %%
# "head" read top 5 rows from table and similarly "tail" last 5 rows.
df_db_customer.head()
# Out:
#    customerid    name country        state  gender                  dob  \
# 0  0002-ORFBO  keshav   India  Maharashtra    Male  1982-04-12 00:00:00
# 1  0003-MKNFE  raghav   India    Karnataka    Male  1995-11-23 00:00:00
# 2  0004-TLHLJ  lalita   India        Delhi  Female  1978-02-15 00:00:00
# 3  0011-IGKFF   mohan   India     Nagaland    Male  2001-08-30 00:00:00
# 4  0013-EXCHZ    mira   India        Delhi  Female  1990-05-05 00:00:00
#
#   interests pincode
# 0    travel    None
# 1       NaN    None
# 2     movie    None
# 3       NaN    None
# 4     drama    None

# %%
# "info" tells DataFrame’s structure with memory usage
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  21 non-null     str
#  1   name        21 non-null     str
#  2   country     18 non-null     str
#  3   state       21 non-null     str
#  4   gender      21 non-null     str
#  5   dob         21 non-null     str
#  6   interests   4 non-null      str
#  7   pincode     0 non-null      object
# dtypes: object(1), str(7)
# memory usage: 1.4+ KB

# %% [markdown]
# ## * Action we perform
# ### 2.1 rename col - name to customer_name
# ### 2.2 drop columns - interest and pincode
# ### 2.3 change data type - dob
# ### 2.4 data standardization - gender
# ### 2.5 fix missing values (using existing data) - country

# %%
# 2.1 rename col - name to customer_name
df_db_customer.rename(columns = {'name' : 'customer_name'}, inplace= True)

# %%
# 2.2 drop columns - interest and pincode
# Another way to drop with columns name
#df_db_customer.drop(columns=['interests', 'pincode'], inplace=True)
df_db_customer.drop(df_db_customer.columns[-2:], axis = 1, inplace = True)

# %%
# 2.3 change data type - dob

df_db_customer['dob'] = pd.to_datetime(df_db_customer['dob'])

# %%
df_db_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerid     21 non-null     str
#  1   customer_name  21 non-null     str
#  2   country        18 non-null     str
#  3   state          21 non-null     str
#  4   gender         21 non-null     str
#  5   dob            21 non-null     datetime64[us]
# dtypes: datetime64[us](1), str(5)
# memory usage: 1.1 KB

# %%
# 2.4 data standardization - gender

# df_db_customer['gender'].unique()
df_db_customer['gender'] = df_db_customer['gender'].replace({'Men' : 'Male', 'Women' : 'Female'})

# %%
df_db_customer['gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
# 2.5 fix missing values - country
df_db_customer[df_db_customer['country'].isna()]
# Out:
#     customerid customer_name country      state  gender        dob
# 5   0013-MHZWF         durga     NaN      Delhi  Female 1988-12-10
# 8   0015-UOCOJ          maya     NaN  Kathmandu  Female 1985-07-07
# 12  0018-NYROU        chitra     NaN  Telangana  Female 2004-12-01

# %%
# country and state - unique value pair

# Creating state → country map from non-null rows
state_country_mapping = df_db_customer.dropna(subset=['country']).set_index('state')['country'].to_dict()

# Fill the missing country using State
df_db_customer['country'] = df_db_customer['country'].fillna(df_db_customer['state'].map(state_country_mapping))

# %%
df_db_customer[df_db_customer['country'].isna()] # no null value in country col.
# Out:
# Empty DataFrame
# Columns: [customerid, customer_name, country, state, gender, dob]
# Index: []

# %%
conn = sqlite3.connect('customer_churn.db')

tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
conn.close()

tables
# Out:
#               name
# 0      db_customer
# 1  db_subscription
# 2       db_support

# %% [markdown]
# ### On Subscription Table

# %%
df_db_subscription.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaN                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaN                     NaN
# 3   Premium        Annual               NaN                     NaN
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  churn_score
# 0            13.99   627           12
# 1            12.99  1150           91
# ...

# %%
df_db_subscription.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     str
#  1   subscription_start_date  21 non-null     str
#  2   subscription_type        21 non-null     str
#  3   renewal_date             21 non-null     str
#  4   plan_type                21 non-null     str
#  5   contract_type            21 non-null     str
#  6   cancellation_date        6 non-null      str
#  7   cancellation_reason      6 non-null      str
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 1.9 KB

# %%
# change data type to date - subscription_start_date , renewal_date, cancellation_date

data_cols = ['subscription_start_date','renewal_date','cancellation_date']
df_db_subscription[data_cols] = df_db_subscription[data_cols].apply(pd.to_datetime)
df_db_subscription.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               21 non-null     str
#  1   subscription_start_date  21 non-null     datetime64[us]
#  2   subscription_type        21 non-null     str
#  3   renewal_date             21 non-null     datetime64[us]
#  4   plan_type                21 non-null     str
#  5   contract_type            21 non-null     str
#  6   cancellation_date        6 non-null      datetime64[us]
#  7   cancellation_reason      6 non-null      str
#  8   monthly_charges          21 non-null     float64
#  9   cltv                     21 non-null     int64
#  10  churn_score              21 non-null     int64
# dtypes: datetime64[us](3), float64(1), int64(2), str(5)
# memory usage: 1.9 KB

# %% [markdown]
# ### On Support Table

# %%
df_db_support.head()
# Out:
#    customerid       complaint_date escalations  csat_score col_1  \
# 0  0003-MKNFE  2024-08-28 00:00:00           N          60  None
# 1  0003-MKNFE  2024-08-28 00:00:00           Y          10  None
# 2  0013-EXCHZ  2024-01-20 00:00:00           Y          20  None
# 3  0013-MHZWF  2025-03-18 00:00:00           N          90  None
# 4  0013-SMEOE  2024-11-01 00:00:00           N          30  None
#
#              comment
# 0      service issue
# 1     demaned refund
# 2                NaN
# 3  guidance to renew
# 4                NaN

# %%
df_db_support.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      str
#  1   complaint_date  9 non-null      str
#  2   escalations     9 non-null      str
#  3   csat_score      9 non-null      int64
#  4   col_1           0 non-null      object
#  5   comment         4 non-null      str
# dtypes: int64(1), object(1), str(4)
# memory usage: 564.0+ bytes

# %%
# a. Change dtype str to datetime
df_db_support['complaint_date'] = pd.to_datetime(df_db_support['complaint_date'])
df_db_support.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      str
#  1   complaint_date  9 non-null      datetime64[us]
#  2   escalations     9 non-null      str
#  3   csat_score      9 non-null      int64
#  4   col_1           0 non-null      object
#  5   comment         4 non-null      str
# dtypes: datetime64[us](1), int64(1), object(1), str(3)
# memory usage: 564.0+ bytes

# %%
# b. drop column col_1 and comment
df_db_support.drop(columns=['col_1', 'comment'], inplace=True)
df_db_support.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerid      9 non-null      str
#  1   complaint_date  9 non-null      datetime64[us]
#  2   escalations     9 non-null      str
#  3   csat_score      9 non-null      int64
# dtypes: datetime64[us](1), int64(1), str(2)
# memory usage: 420.0 bytes

# %% [markdown]
# ## 3. Feature Engineering and Data Analysis

# %%
# create a new col using existing cols named churn flag

# Customer is churned if cancellation_date is not null
df_db_subscription['churn_flag'] = np.where(df_db_subscription['cancellation_date'].notna(), 1, 0)
df_db_subscription.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 3  0011-IGKFF              2019-05-10              Paid   2025-05-10
# 4  0013-EXCHZ              2023-01-05          Refferal   2024-01-05
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2     Basic       Monthly               NaT                     NaN
# 3   Premium        Annual               NaT                     NaN
# 4  Standard       Monthly        2024-02-28           Too expensive
#
#    monthly_charges  cltv  churn_score  churn_flag
# 0            13.99   627           12           0
# ...

# %% [markdown]
# ### Merge all table with common cols (customer id)

# %%
# Check duplicates in df with shape/size before and after
# first fix support table duplicates then merge
merge_df = (df_db_subscription
    .merge(df_db_customer, on = 'customerid', how= 'left')
    .merge(df_db_support, on = 'customerid', how= 'left'))

# %%
merge_df.head()
# Out:
#    customerid subscription_start_date subscription_type renewal_date  \
# 0  0002-ORFBO              2021-03-15          Refferal   2025-03-15
# 1  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 2  0003-MKNFE              2020-08-01              Paid   2024-08-01
# 3  0004-TLHLJ              2022-11-20           Organic   2025-11-20
# 4  0011-IGKFF              2019-05-10              Paid   2025-05-10
#
#   plan_type contract_type cancellation_date     cancellation_reason  \
# 0  Standard        Annual               NaT                     NaN
# 1   Premium        Annual        2024-09-10  Switched to competitor
# 2   Premium        Annual        2024-09-10  Switched to competitor
# 3     Basic       Monthly               NaT                     NaN
# 4   Premium        Annual               NaT                     NaN
#
#    monthly_charges  cltv  churn_score  churn_flag customer_name country  \
# ...

# %%
merge_df.info()
merge_df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerid               23 non-null     str
#  1   subscription_start_date  23 non-null     datetime64[us]
#  2   subscription_type        23 non-null     str
#  3   renewal_date             23 non-null     datetime64[us]
#  4   plan_type                23 non-null     str
#  5   contract_type            23 non-null     str
#  6   cancellation_date        8 non-null      datetime64[us]
#  7   cancellation_reason      8 non-null      str
#  8   monthly_charges          23 non-null     float64
#  9   cltv                     23 non-null     int64
#  10  churn_score              23 non-null     int64
#  11  churn_flag               23 non-null     int64
#  12  customer_name            23 non-null     str
#  13  country                  23 non-null     str
# ...

# %%
# Group duplicate complaint and store in new column named complaint_count
df_db_support['complaint_count'] = df_db_support.groupby('customerid')['customerid'].transform('count')
df_db_support
# Out:
#    customerid complaint_date escalations  csat_score  complaint_count
# 0  0003-MKNFE     2024-08-28           N          60                2
# 1  0003-MKNFE     2024-08-28           Y          10                2
# 2  0013-EXCHZ     2024-01-20           Y          20                1
# 3  0013-MHZWF     2025-03-18           N          90                1
# 4  0013-SMEOE     2024-11-01           N          30                1
# 5  0017-IUDMW     2024-04-10           Y          25                1
# 6  0019-EFAEP     2024-09-27           Y          30                1
# 7  0022-TCJCI     2024-09-13           Y          10                2
# 8  0022-TCJCI     2024-09-14           N          90                2

# %%
# Sort and remove/drop duplicates and keep last complaint
df_db_support = df_db_support.sort_values('complaint_date').drop_duplicates('customerid', keep= 'last')

# %%
df_db_support.shape
# Out:
# (7, 5)

# %%
# Merge dataframe
merge_df = (df_db_subscription
    .merge(df_db_customer, on = 'customerid', how= 'left')
    .merge(df_db_support, on = 'customerid', how= 'left'))

# %%
merge_df.shape
# Out:
# (21, 21)

# %% [markdown]
# ### Now Data Analysis

# %%
merge_df.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count'],
#       dtype='str')

# %%
# 3.1 Get churn rate
churn_rate = merge_df['churn_flag'].mean()*100
print("Churn Rate = ", round(churn_rate,2), "%")
# Out:
# Churn Rate =  28.57 %

# %%
# 3.2 Retenion Rate
retention_rate = 100 - churn_rate
print("Retention Rate = ", round(retention_rate,2), "%")
# Out:
# Retention Rate =  71.43 %

# %%
# 3.3 Churn by Plan type
churn_by_plan = (merge_df.groupby('plan_type')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_pct'))
churn_by_plan
# Out:
#   plan_type  churn_rate_pct
# 0     Basic           60.00
# 1   Premium           14.29
# 2  Standard           22.22

# %%
 # 3.4 a. Churn by state + sum(revenue) & count of users  -- home work **
churn_by_state = (merge_df.groupby('state')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_state'))

# %%
#  3.4 b. Churn by subscription type + sum(revenue) & count of users   -- home work **
subscription_type = (merge_df.groupby('subscription_type')['churn_flag'].mean().mul(100).round(2).reset_index(name='churn_rate_subscription'))
subscription_type
# Out:
#   subscription_type  churn_rate_subscription
# 0           Organic                     0.00
# 1              Paid                    16.67
# 2          Refferal                    83.33

# %%
# 3.6 ARPU - Avg Revenue per user
arpu = merge_df['monthly_charges'].mean()
print('ARPU = ', round(arpu,2))
# Out:
# ARPU =  18.85

# %%
# 3.7 Avg Customer Tenure
# count of days users has used our service : cancellation date else current date
today = pd.Timestamp.today()

merge_df['tenure_days'] = np.where(
        merge_df['cancellation_date'].notna(),

    (merge_df['cancellation_date'] - merge_df['subscription_start_date']).dt.days,

    (today - merge_df['subscription_start_date']).dt.days
)

avg_tenure = merge_df['tenure_days'].mean()
print("Avg Tenure (Days) = ", round(avg_tenure))
# Out:
# Avg Tenure (Days) =  1531

# %%
# 3.8 Revenue at risk - revenue lost from churned users
revenue_at_risk = merge_df.loc[merge_df['churn_flag']==1, 'monthly_charges'].sum()
print("Revenue at Risk (In Rs.) =", revenue_at_risk, "K")
# Out:
# Revenue at Risk (In Rs.) = 73.94 K

# %%
# 3.9 Esclation Rate
escalation_rate = (merge_df['escalations']=='Y').mean()*100
print("Esclation Rate = ", round(escalation_rate, 2), "%")
# Out:
# Esclation Rate =  19.05 %

# %%
# 3.10 Avg Complaint Per User
avg_complaints = merge_df['complaint_count'].sum() / merge_df['customerid'].nunique()
print("Avg Compliants Per User = ", round(avg_complaints, 2))
# Out:
# Avg Compliants Per User =  0.43

# %%
# 3.11 Correlation Esclation vs Churn
merge_df['escalations'] = np.where(merge_df['escalations'] == 'Y', 1, 0) # encoding string to int type
corr_df = merge_df[['escalations', 'churn_flag']].dropna()     

correlation = corr_df['escalations'].corr(merge_df['churn_flag'])
print("Correlation between esclation vs churn is = ", round(correlation,2))
# Out:
# Correlation between esclation vs churn is =  0.77

# %%
# 3.12 Create a column using existing col - Churn risk
conditions = [
        (merge_df['churn_score'] < 50),
        (merge_df['churn_score'] >= 50) & (merge_df['churn_score'] < 70),
        (merge_df['churn_score'] >= 70)
]

choices = ['low', 'med', 'high']

merge_df['churn_risk'] = np.select(conditions, choices, default='unkown')
merge_df[['churn_score','churn_risk']]
# Out:
#     churn_score churn_risk
# 0            12        low
# 1            91       high
# 2            34        low
# 3             8        low
# 4            88       high
# 5            22        low
# 6            79       high
# 7             5        low
# 8            34        low
# 9            41        low
# 10           14        low
# 11           83       high
# 12           19        low
# 13           76       high
# 14            3        low
# 15           58        med
# 16           62        med
# 17           27        low
# 18           99       high
# 19            7        low
# 20           47        low

# %% [markdown]
# ## 4. Visualization using Matplotlib

# %%
# To safely preserve the original, create a copy of merge_df
df_visual = merge_df.copy()
df_visual.columns
# Out:
# Index(['customerid', 'subscription_start_date', 'subscription_type',
#        'renewal_date', 'plan_type', 'contract_type', 'cancellation_date',
#        'cancellation_reason', 'monthly_charges', 'cltv', 'churn_score',
#        'churn_flag', 'customer_name', 'country', 'state', 'gender', 'dob',
#        'complaint_date', 'escalations', 'csat_score', 'complaint_count',
#        'tenure_days', 'churn_risk'],
#       dtype='str')

# %%
# 4.1 Monthly Churn Trend (Time Series KPI)
df_visual['cancellation_month'] = df_visual['cancellation_date'].dt.to_period('M')

churn_trend = df_visual[df_visual['churn_flag'] == 1].groupby('cancellation_month').size()

plt.figure(figsize=(8,3))
plt.plot(churn_trend.index.astype(str), churn_trend.values,  color='blue', marker='o', linestyle='dashed',  linewidth=2, markersize=5,)

plt.title('Monthly Churn Trend')
plt.xlabel('Month')
plt.ylabel('Churned Customers')
plt.show()

# %%
# 4.2 Churn Rate by Plan type
churn_plan = df_visual.groupby('plan_type')['churn_flag'].mean()

# colors = ['yellow', 'purple', 'blue']
colors = plt.cm.Set2(np.linspace(0, 1, len(churn_plan)))

plt.figure(figsize=(7,4))
plt.bar(churn_plan.index, churn_plan.values, color = colors)

plt.title('Churn Rate by Plan Type')
plt.xlabel('Plan Type')
plt.ylabel('Churn Rate (%)')
plt.show()
